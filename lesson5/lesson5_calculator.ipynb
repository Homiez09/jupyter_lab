# %% [markdown]
# ### วิธีเรียงสับเปลี่ยน (Permutation)

# %% [markdown]
# จากสูตร

# %% [markdown]
# ![Screen Shot 2565-12-18 at 02.03.34.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import statistics
import scipy
from scipy import stats
from math import perm, comb
from ipywidgets import interact
from ipywidgets import widgets

# %%
#input UI
n_intText = widgets.IntText(value=1,
                                description='n=',
                                orientation='horizontal',
                                readout=True)
r_intText = widgets.IntText(value=1,
                                description='r=',
                                orientation='horizontal',
                                readout=True)

ui = widgets.VBox([n_intText, r_intText])


#output
def cal_perm(n, r):
  n_event = perm(n, r)
  P_label = widgets.Label(value=f"Number of possible events: {n_event}")
  display(P_label)
 
out = widgets.interactive_output(cal_perm, {'n':n_intText,
                                            'r':r_intText})
display(ui, out)
# Out:
# VBox(children=(IntText(value=1, description='n='), IntText(value=1, description='r=')))
# Output()

# %% [markdown]
# ---

# %% [markdown]
# ### วิธีจัดหมู่ (Combination)

# %% [markdown]
# จากสูตร

# %% [markdown]
# ![Screen Shot 2565-12-18 at 19.19.37.png](data:image/png;base64,...)

# %%
#input UI
n_intText = widgets.IntText(value=1,
                                description='n=',
                                orientation='horizontal',
                                readout=True)
r_intText = widgets.IntText(value=1,
                                description='r=',
                                orientation='horizontal',
                                readout=True)

ui = widgets.VBox([n_intText, r_intText])


#output
def cal_comb(n, r):
  n_event = comb(n, r)
  P_label = widgets.Label(value=f"Number of possible events: {n_event}")
  display(P_label)
 
out = widgets.interactive_output(cal_comb, {'n':n_intText,
                                            'r':r_intText})
display(ui, out)
# Out:
# VBox(children=(IntText(value=1, description='n='), IntText(value=1, description='r=')))
# Output()
